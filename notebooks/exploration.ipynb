# %% [markdown]
# # Metric exploration
#
# After generating `data/raw/metrics.csv` with `python src/generate_data.py`, use this notebook for EDA: distributions, correlations, anomaly rate, and time-series plots.

# %%
# import pandas as pd
# df = pd.read_csv("../data/raw/metrics.csv", parse_dates=["timestamp"])
# df.head()
